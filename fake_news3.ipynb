# %%
# libraries for data manipulation and exploration
import pandas as pd
import numpy as np

# for text processing
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM, Dense, Conv1D, Conv2D, MaxPooling1D, Dropout, SimpleRNN
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
import nltk
import tensorflow as tf
from sklearn.linear_model import Lasso
#nltk.download('wordnet')

# %%
data = pd.read_csv(r'/content/data.csv')
#data.head
#data.info()
# dropping rows where there is any null value
data.dropna(inplace=True, axis=0)

# taking only the name of website from the URLs
pattern = 'https?://([\w.]+)/'
data['Website'] = data.URLs.str.extract(pattern)
data.drop('URLs', axis=1, inplace=True)

# making a bar plot to count the frequency of 
# fake and real news
#sns.countplot(x='Label', 
 #             data=data,
  #            palette=['#ffaec0', '#b8b5ff'],
   #           saturation=1)
#sns.despine()
#plt.xticks([0,1], ['Fake', 'Real'])
#plt.title('Fake Vs Real news');

# %%
fake_news_count = data[data.Label == 0]['Website'].value_counts()
real_news_count = data[data.Label == 1]['Website'].value_counts()

fdf = pd.DataFrame({
    'Web':fake_news_count.index,
    'Fake':fake_news_count.values
})

rdf = pd.DataFrame({
    'Web':real_news_count.index,
    'Real':real_news_count.values
})

rf_count = pd.merge(rdf, fdf, on='Web', how='outer').fillna(0)
rf_count['Real'] = rf_count['Real'].astype(int)
rf_count['Fake'] = rf_count['Fake'].astype(int)
rf_count
# Out:
#                           Web  Real  Fake
# 0             www.reuters.com   646     0
# 1                 www.cnn.com   389     0
# 2             www.nytimes.com   341     0
# 3                 www.bbc.com   333     0
# 4              abcnews.go.com    57     0
# 5               money.cnn.com    49     0
# 6             edition.cnn.com    15     0
# 7            inhealth.cnn.com    14     0
# 8               www.bbc.co.uk    10     0
# 9          bleacherreport.com     8     0
# 10              clarivate.com     3     0
# 11                reuters.com     1     0
# 12                     cnn.it     1     0
# 13  thelab.bleacherreport.com     1     0
# 14          beforeitsnews.com     0  1681
# 15       www.activistpost.com     0   267
# 16          dailybuzzlive.com     0    99
# 17            www.disclose.tv     0    71

# %%
sns.barplot(y=real_news_count[:5].index, x=real_news_count[:5].values, 
            palette=['#7868e6', '#b8b5ff', '#ffaec0', 'grey', '#a7c5eb'])
sns.despine(bottom=True, left=True)
plt.title('Top 5 websites posting Real News');

# %%
sns.barplot(y=fake_news_count.index, x=fake_news_count.values,
            palette=['#7868e6', '#b8b5ff', '#ffaec0', 'grey'])
sns.despine(bottom=True, left=True)
plt.title('Top websites posting Fake News');

# %%
lm = WordNetLemmatizer()
def clean_text(column):
    corpus = []
    for value in column:
        # convert each word into lower case
        value = value.lower()
        # take only alphabets
        value = re.sub('[^a-z]', ' ', value)
        value = value.split()
        # lemmatizing those words which are not stop words
        value = [lm.lemmatize(word) for word in value\
                 if word not in set(stopwords.words('english'))]
        corpus.append(' '.join(value))
    return corpus    

# taking both headline and body of news into a single column
data['Text'] = data['Headline'] + ' ' + data['Body']
data['Text'] = clean_text(data.Text)

sw = set(STOPWORDS)

fake_news = data[data.Label == 0]
real_news = data[data.Label == 1]

# wordcloud for fake news
fake_wc = WordCloud(width = 1200, height = 600, 
                    background_color ='white', 
                    stopwords = sw, 
                    min_font_size = 10).generate(' '.join(fake_news.Text)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (12, 6), facecolor = None) 
plt.imshow(fake_wc) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('Word Cloud for fake news', fontsize=20);

# %%
# wordcloud for real news
real_wc = WordCloud(width = 1200, height = 600, 
                    background_color ='white', 
                    stopwords = sw, 
                    min_font_size = 10).generate(' '.join(real_news.Text)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (12, 6), facecolor = None) 
plt.imshow(real_wc) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('Word Cloud for real news', fontsize=20);

# %%
# one hot representation of words
oh_repr = [one_hot(words, 5000) for words in data.Text]

# list to store length of words in each news
len_list = []
for w in data.Text:
    w = w.split()
    len_list.append(len(w))

print('Summary of word length :')
pd.Series(len_list).describe()
# Out:
# Summary of word length :
# count    3988.000000
# mean      289.271063
# std       289.423529
# min        10.000000
# 25%        65.000000
# 50%       217.000000
# 75%       419.000000
# max      3171.000000
# dtype: float64

# %%
# taking sentences length as 400
sent_length = 400
# padding
embedded_doc = pad_sequences(oh_repr, padding='pre', maxlen=sent_length)
embedded_doc[:5]
# Out:
# array([[ 612, 3570,  303, ..., 1967, 4181, 4104],
#        [   0,    0,    0, ..., 4290,  680, 2509],
#        [ 350, 3260, 4427, ..., 3882,  499, 2051],
#        [   0,    0,    0, ..., 1198, 3683, 4425],
#        [   0,    0,    0, ..., 3391,  808, 3822]], dtype=int32)

# %%
x = np.array(embedded_doc)
y = data.Label


las = Lasso(alpha=1.0)
las.fit(x, y)
# Out:
# Lasso()

# %%
model = Sequential()
# adding embedding layer
model.add(Embedding(5000, 100, input_length=sent_length))
model.add(LSTM(150))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 400, 100)          500000
#
#  lstm (LSTM)                 (None, 150)               150600
#
#  dense (Dense)               (None, 1)                 151
#
# =================================================================
# Total params: 650,751
# Trainable params: 650,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# splitting the dataset into train and test
train_x, test_x, train_y, test_y = train_test_split(x, y, 
                                                    test_size=0.2, random_state=3)



METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
]

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS,
)

# fitting the model
history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 59s 1s/step - loss: 0.4554 - accuracy: 1.0000 - precision: 0.8651 - recall: 0.7686 - auc: 0.9238 - val_loss: 0.1592 - val_accuracy: 1.0000 - val_precision: 0.8920 - val_recall: 0.9909 - val_auc: 0.9885
# Epoch 2/50
# 44/44 [==============================] - 48s 1s/step - loss: 0.0746 - accuracy: 1.0000 - precision: 0.9595 - recall: 0.9879 - auc: 0.9956 - val_loss: 0.0772 - val_accuracy: 1.0000 - val_precision: 0.9510 - val_recall: 0.9873 - val_auc: 0.9967
# Epoch 3/50
# 44/44 [==============================] - 51s 1s/step - loss: 0.0115 - accuracy: 1.0000 - precision: 0.9955 - recall: 0.9992 - auc: 0.9999 - val_loss: 0.0681 - val_accuracy: 1.0000 - val_precision: 0.9731 - val_recall: 0.9873 - val_auc: 0.9963
# Epoch 4/50
# 44/44 [==============================] - 48s 1s/step - loss: 0.0031 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9992 - auc: 1.0000 - val_loss: 0.0805 - val_accuracy: 1.0000 - val_precision: 0.9596 - val_recall: 0.9945 - val_auc: 0.9953
# Epoch 5/50
# 44/44 [==============================] - 47s 1s/step - loss: 0.0016 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0885 - val_accuracy: 1.0000 - val_precision: 0.9680 - val_recall: 0.9891 - val_auc: 0.9906
# Epoch 6/50
# 44/44 [==============================] - 47s 1s/step - loss: 6.1138e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0907 - val_accuracy: 1.0000 - val_precision: 0.9697 - val_recall: 0.9891 - val_auc: 0.9911
# Epoch 7/50
# 44/44 [==============================] - 47s 1s/step - loss: 3.2522e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0997 - val_accuracy: 1.0000 - val_precision: 0.9696 - val_recall: 0.9855 - val_auc: 0.9896
# Epoch 8/50
# 44/44 [==============================] - 46s 1s/step - loss: 2.1968e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1148 - val_accuracy: 1.0000 - val_precision: 0.9679 - val_recall: 0.9855 - val_auc: 0.9881
# Epoch 9/50
# 44/44 [==============================] - 48s 1s/step - loss: 1.6049e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1191 - val_accuracy: 1.0000 - val_precision: 0.9677 - val_recall: 0.9818 - val_auc: 0.9881
# Epoch 10/50
# 44/44 [==============================] - 47s 1s/step - loss: 1.2510e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1277 - val_accuracy: 1.0000 - val_precision: 0.9677 - val_recall: 0.9818 - val_auc: 0.9872
# Epoch 11/50
# 44/44 [==============================] - 48s 1s/step - loss: 1.0135e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1389 - val_accuracy: 1.0000 - val_precision: 0.9626 - val_recall: 0.9818 - val_auc: 0.9857
# Epoch 12/50
# 44/44 [==============================] - 47s 1s/step - loss: 8.4578e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1410 - val_accuracy: 1.0000 - val_precision: 0.9643 - val_recall: 0.9818 - val_auc: 0.9865
# Epoch 13/50
# 44/44 [==============================] - 47s 1s/step - loss: 7.0847e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1523 - val_accuracy: 1.0000 - val_precision: 0.9609 - val_recall: 0.9818 - val_auc: 0.9850
# Epoch 14/50
# 44/44 [==============================] - 48s 1s/step - loss: 6.0365e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1482 - val_accuracy: 1.0000 - val_precision: 0.9643 - val_recall: 0.9818 - val_auc: 0.9857
# Epoch 15/50
# 44/44 [==============================] - 47s 1s/step - loss: 5.2334e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1582 - val_accuracy: 1.0000 - val_precision: 0.9643 - val_recall: 0.9818 - val_auc: 0.9841
# Epoch 16/50
# 44/44 [==============================] - 47s 1s/step - loss: 4.5271e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1598 - val_accuracy: 1.0000 - val_precision: 0.9642 - val_recall: 0.9800 - val_auc: 0.9832
# Epoch 17/50
# 44/44 [==============================] - 48s 1s/step - loss: 3.9568e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1704 - val_accuracy: 1.0000 - val_precision: 0.9625 - val_recall: 0.9800 - val_auc: 0.9823
# Epoch 18/50
# 44/44 [==============================] - 47s 1s/step - loss: 3.4739e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1683 - val_accuracy: 1.0000 - val_precision: 0.9642 - val_recall: 0.9800 - val_auc: 0.9832
# Epoch 19/50
# 44/44 [==============================] - 47s 1s/step - loss: 3.0809e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1701 - val_accuracy: 1.0000 - val_precision: 0.9642 - val_recall: 0.9800 - val_auc: 0.9832
# Epoch 20/50
# 44/44 [==============================] - 48s 1s/step - loss: 2.7862e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1720 - val_accuracy: 1.0000 - val_precision: 0.9642 - val_recall: 0.9782 - val_auc: 0.9832
# Epoch 21/50
# 44/44 [==============================] - 47s 1s/step - loss: 2.5148e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1823 - val_accuracy: 1.0000 - val_precision: 0.9625 - val_recall: 0.9800 - val_auc: 0.9824
# Epoch 22/50
# 44/44 [==============================] - 48s 1s/step - loss: 0.0264 - accuracy: 1.0000 - precision: 0.9954 - recall: 0.9901 - auc: 0.9997 - val_loss: 0.1181 - val_accuracy: 1.0000 - val_precision: 0.9338 - val_recall: 0.9745 - val_auc: 0.9890
# Epoch 23/50
# 44/44 [==============================] - 52s 1s/step - loss: 0.0158 - accuracy: 1.0000 - precision: 0.9902 - recall: 0.9962 - auc: 0.9999 - val_loss: 0.0821 - val_accuracy: 1.0000 - val_precision: 0.9692 - val_recall: 0.9727 - val_auc: 0.9950
# Epoch 24/50
# 44/44 [==============================] - 50s 1s/step - loss: 0.0019 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9992 - auc: 1.0000 - val_loss: 0.0918 - val_accuracy: 1.0000 - val_precision: 0.9658 - val_recall: 0.9745 - val_auc: 0.9930
# Epoch 25/50
# 44/44 [==============================] - 49s 1s/step - loss: 5.3826e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000 - val_precision: 0.9662 - val_recall: 0.9873 - val_auc: 0.9918
# Epoch 26/50
# 44/44 [==============================] - 50s 1s/step - loss: 3.0169e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0982 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9919
# Epoch 27/50
# 44/44 [==============================] - 48s 1s/step - loss: 2.1786e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1021 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9873 - val_auc: 0.9913
# Epoch 28/50
# 44/44 [==============================] - 49s 1s/step - loss: 1.7252e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1050 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9891 - val_auc: 0.9914
# Epoch 29/50
# 44/44 [==============================] - 48s 1s/step - loss: 1.4026e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1062 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9891 - val_auc: 0.9914
# Epoch 30/50
# 44/44 [==============================] - 48s 1s/step - loss: 1.1796e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1089 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9891 - val_auc: 0.9907
# Epoch 31/50
# 44/44 [==============================] - 49s 1s/step - loss: 1.0129e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1107 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9891 - val_auc: 0.9907
# Epoch 32/50
# 44/44 [==============================] - 48s 1s/step - loss: 8.8322e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1126 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9891 - val_auc: 0.9908
# Epoch 33/50
# 44/44 [==============================] - 50s 1s/step - loss: 7.7844e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1137 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9891 - val_auc: 0.9908
# Epoch 34/50
# 44/44 [==============================] - 51s 1s/step - loss: 6.9391e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1155 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9901
# Epoch 35/50
# 44/44 [==============================] - 50s 1s/step - loss: 6.2135e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1160 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9893
# Epoch 36/50
# 44/44 [==============================] - 51s 1s/step - loss: 5.6194e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1176 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 37/50
# 44/44 [==============================] - 49s 1s/step - loss: 5.1034e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1185 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 38/50
# 44/44 [==============================] - 50s 1s/step - loss: 4.6617e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1196 - val_accuracy: 1.0000 - val_precision: 0.9662 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 39/50
# 44/44 [==============================] - 50s 1s/step - loss: 4.2671e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1207 - val_accuracy: 1.0000 - val_precision: 0.9662 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 40/50
# 44/44 [==============================] - 50s 1s/step - loss: 3.9298e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1219 - val_accuracy: 1.0000 - val_precision: 0.9662 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 41/50
# 44/44 [==============================] - 50s 1s/step - loss: 3.6257e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1226 - val_accuracy: 1.0000 - val_precision: 0.9662 - val_recall: 0.9873 - val_auc: 0.9894
# Epoch 42/50
# 44/44 [==============================] - 50s 1s/step - loss: 3.3581e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1238 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9872
# Epoch 43/50
# 44/44 [==============================] - 49s 1s/step - loss: 3.1168e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1248 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9872
# Epoch 44/50
# 44/44 [==============================] - 50s 1s/step - loss: 2.9024e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1259 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9872
# Epoch 45/50
# 44/44 [==============================] - 49s 1s/step - loss: 2.7107e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1269 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865
# Epoch 46/50
# 44/44 [==============================] - 49s 1s/step - loss: 2.5361e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1273 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865
# Epoch 47/50
# 44/44 [==============================] - 50s 1s/step - loss: 2.3774e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1282 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865
# Epoch 48/50
# 44/44 [==============================] - 49s 1s/step - loss: 2.2345e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1293 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865
# Epoch 49/50
# 44/44 [==============================] - 50s 1s/step - loss: 2.1039e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1297 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865
# Epoch 50/50
# 44/44 [==============================] - 48s 1s/step - loss: 1.9835e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1308 - val_accuracy: 1.0000 - val_precision: 0.9645 - val_recall: 0.9873 - val_auc: 0.9865

# %%
pred = (model.predict(test_x) > 0.5).astype("int32")

print ( classification_report(pred, test_y))

cm = confusion_matrix(test_y, pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='', cbar=False, linewidths=2,
            xticklabels = ['Fake','Real'], yticklabels = ['Fake','Real'])
plt.title('confusion matrix')
plt.xlabel('Predicted', color='navy', fontsize=15)
plt.ylabel('Actual', color='navy', fontsize=15);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       416
#            1       0.98      0.96      0.97       382
#
#     accuracy                           0.97       798
#    macro avg       0.97      0.97      0.97       798
# weighted avg       0.97      0.97      0.97       798

# %%
#from the confusion matrix it is obvious and clear we have 416 fake news and 367 real news, it isn't imbalanced

# %%
acc = history.history['recall']
val_acc = history.history['val_recall']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['val_loss']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Recall')
plt.scatter(epochs_range, val_acc, label='Validation Recall')
plt.legend(loc='lower right')
plt.title('Training and Validation Recall')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Loss')
plt.scatter(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# initializing model
model1 = Sequential()
# adding embedding layer
model1.add(Embedding(5000, 100, input_length=sent_length))
model1.add(Conv1D(filters=28,kernel_size=7,activation='relu'))
MaxPooling1D(pool_size=2) 
Dropout(0.3)
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 400, 100)          500000
#
#  conv1d_1 (Conv1D)           (None, 394, 28)           19628
#
#  dense_2 (Dense)             (None, 394, 1)            29
#
# =================================================================
# Total params: 519,657
# Trainable params: 519,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS,
)

# %%
# fitting the model
history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 57s 1s/step - loss: 0.0195 - accuracy: 1.0000 - precision: 0.9953 - recall: 0.9933 - auc: 0.9988 - val_loss: 0.1536 - val_accuracy: 1.0000 - val_precision: 0.9603 - val_recall: 0.9732 - val_auc: 0.9857
# Epoch 2/50
# 50/50 [==============================] - 54s 1s/step - loss: 0.0045 - accuracy: 1.0000 - precision: 0.9993 - recall: 0.9993 - auc: 0.9997 - val_loss: 0.1290 - val_accuracy: 1.0000 - val_precision: 0.9730 - val_recall: 0.9651 - val_auc: 0.9862
# Epoch 3/50
# 50/50 [==============================] - 52s 1s/step - loss: 3.9099e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1344 - val_accuracy: 1.0000 - val_precision: 0.9628 - val_recall: 0.9705 - val_auc: 0.9873
# Epoch 4/50
# 50/50 [==============================] - 53s 1s/step - loss: 1.7724e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1401 - val_accuracy: 1.0000 - val_precision: 0.9603 - val_recall: 0.9732 - val_auc: 0.9875
# Epoch 5/50
# 50/50 [==============================] - 52s 1s/step - loss: 1.2051e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1452 - val_accuracy: 1.0000 - val_precision: 0.9631 - val_recall: 0.9786 - val_auc: 0.9865
# Epoch 6/50
# 50/50 [==============================] - 51s 1s/step - loss: 9.1129e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1491 - val_accuracy: 1.0000 - val_precision: 0.9632 - val_recall: 0.9812 - val_auc: 0.9866
# Epoch 7/50
# 50/50 [==============================] - 53s 1s/step - loss: 7.2766e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1525 - val_accuracy: 1.0000 - val_precision: 0.9632 - val_recall: 0.9812 - val_auc: 0.9866
# Epoch 8/50
# 50/50 [==============================] - 52s 1s/step - loss: 6.0167e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1556 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9856
# Epoch 9/50
# 50/50 [==============================] - 54s 1s/step - loss: 5.0954e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1585 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9832
# Epoch 10/50
# 50/50 [==============================] - 52s 1s/step - loss: 4.3950e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1611 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9832
# Epoch 11/50
# 50/50 [==============================] - 52s 1s/step - loss: 3.8492e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1632 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9833
# Epoch 12/50
# 50/50 [==============================] - 52s 1s/step - loss: 3.3971e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1652 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9833
# Epoch 13/50
# 50/50 [==============================] - 52s 1s/step - loss: 3.0355e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1673 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 14/50
# 50/50 [==============================] - 52s 1s/step - loss: 3.3735e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1658 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9833
# Epoch 15/50
# 50/50 [==============================] - 51s 1s/step - loss: 2.5513e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1683 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9833
# Epoch 16/50
# 50/50 [==============================] - 52s 1s/step - loss: 2.2946e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1705 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9833
# Epoch 17/50
# 50/50 [==============================] - 50s 1s/step - loss: 2.0854e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1728 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 18/50
# 50/50 [==============================] - 50s 997ms/step - loss: 1.9059e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1745 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 19/50
# 50/50 [==============================] - 51s 1s/step - loss: 1.7522e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1764 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 20/50
# 50/50 [==============================] - 50s 1s/step - loss: 1.6188e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1780 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 21/50
# 50/50 [==============================] - 52s 1s/step - loss: 1.4997e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1794 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 22/50
# 50/50 [==============================] - 50s 1s/step - loss: 1.3977e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1811 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 23/50
# 50/50 [==============================] - 51s 1s/step - loss: 1.3057e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1824 - val_accuracy: 1.0000 - val_precision: 0.9633 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 24/50
# 50/50 [==============================] - 51s 1s/step - loss: 1.2205e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1835 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9834
# Epoch 25/50
# 50/50 [==============================] - 50s 1s/step - loss: 1.1424e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1851 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 26/50
# 50/50 [==============================] - 51s 1s/step - loss: 1.0728e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1864 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 27/50
# 50/50 [==============================] - 50s 1s/step - loss: 1.0096e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1873 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 28/50
# 50/50 [==============================] - 50s 1s/step - loss: 9.5129e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1885 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 29/50
# 50/50 [==============================] - 50s 994ms/step - loss: 8.9902e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1898 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 30/50
# 50/50 [==============================] - 49s 985ms/step - loss: 8.5212e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1913 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 31/50
# 50/50 [==============================] - 50s 998ms/step - loss: 8.0685e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1923 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 32/50
# 50/50 [==============================] - 49s 983ms/step - loss: 7.6280e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1932 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 33/50
# 50/50 [==============================] - 50s 1s/step - loss: 7.2264e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1942 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 34/50
# 50/50 [==============================] - 49s 990ms/step - loss: 6.8548e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1952 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 35/50
# 50/50 [==============================] - 49s 990ms/step - loss: 6.5227e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1962 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 36/50
# 50/50 [==============================] - 50s 1s/step - loss: 6.1998e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1972 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 37/50
# 50/50 [==============================] - 49s 991ms/step - loss: 5.9024e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1983 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 38/50
# 50/50 [==============================] - 51s 1s/step - loss: 5.8259e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1993 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 39/50
# 50/50 [==============================] - 52s 1s/step - loss: 5.4232e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2001 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9835
# Epoch 40/50
# 50/50 [==============================] - 50s 1s/step - loss: 5.1610e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2012 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 41/50
# 50/50 [==============================] - 50s 1000ms/step - loss: 4.9163e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2020 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 42/50
# 50/50 [==============================] - 50s 996ms/step - loss: 4.6896e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2029 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 43/50
# 50/50 [==============================] - 51s 1s/step - loss: 4.4785e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2040 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 44/50
# 50/50 [==============================] - 50s 999ms/step - loss: 4.2831e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2046 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 45/50
# 50/50 [==============================] - 51s 1s/step - loss: 4.0997e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2056 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 46/50
# 50/50 [==============================] - 49s 985ms/step - loss: 3.9267e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2064 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 47/50
# 50/50 [==============================] - 50s 1000ms/step - loss: 3.7643e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2071 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 48/50
# 50/50 [==============================] - 49s 978ms/step - loss: 3.6128e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2082 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 49/50
# 50/50 [==============================] - 49s 978ms/step - loss: 3.4656e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2091 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9824
# Epoch 50/50
# 50/50 [==============================] - 49s 985ms/step - loss: 3.3254e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2098 - val_accuracy: 1.0000 - val_precision: 0.9607 - val_recall: 0.9839 - val_auc: 0.9825

# %%
pred1 = (model1.predict(test_x) > 0.5).astype("int32")

print ( classification_report(pred, test_y))

cm = confusion_matrix(test_y, pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='', cbar=False, linewidths=2,
            xticklabels = ['Fake','Real'], yticklabels = ['Fake','Real'])
plt.title('confusion matrix')
plt.xlabel('Predicted', color='navy', fontsize=15)
plt.ylabel('Actual', color='navy', fontsize=15);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       414
#            1       0.99      0.96      0.97       384
#
#     accuracy                           0.97       798
#    macro avg       0.97      0.97      0.97       798
# weighted avg       0.97      0.97      0.97       798

# %%
acc = history.history['recall']
val_acc = history.history['val_recall']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['val_loss']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Recall')
plt.scatter(epochs_range, val_acc, label='Validation Recall')
plt.legend(loc='lower right')
plt.title('Training and Validation Recall')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Loss')
plt.scatter(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model3 = Sequential()
# adding embedding layer
model3.add(Embedding(5000, 100, input_length=sent_length))
model3.add(SimpleRNN(150))
model3.add(Dense(1, activation='sigmoid'))
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 400, 100)          500000
#
#  simple_rnn (SimpleRNN)      (None, 150)               37650
#
#  dense_3 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 537,801
# Trainable params: 537,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# splitting the dataset into train and test
train_x, test_x, train_y, test_y = train_test_split(x, y, 
                                                    test_size=0.2, random_state=3)



METRICS = [
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
]

# %%
model3.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=METRICS,
)

# fitting the model
history = model3.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 19s 325ms/step - loss: 0.5141 - accuracy: 1.0000 - precision: 0.7516 - recall: 0.7064 - auc: 0.8525 - val_loss: 0.3980 - val_accuracy: 1.0000 - val_precision: 0.8693 - val_recall: 0.8740 - val_auc: 0.9555
# Epoch 2/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.1693 - accuracy: 1.0000 - precision: 0.9348 - recall: 0.9679 - auc: 0.9841 - val_loss: 0.1089 - val_accuracy: 1.0000 - val_precision: 0.9340 - val_recall: 0.9866 - val_auc: 0.9927
# Epoch 3/50
# 50/50 [==============================] - 15s 308ms/step - loss: 0.0395 - accuracy: 1.0000 - precision: 0.9821 - recall: 0.9920 - auc: 0.9993 - val_loss: 0.0856 - val_accuracy: 1.0000 - val_precision: 0.9602 - val_recall: 0.9705 - val_auc: 0.9937
# Epoch 4/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.0447 - accuracy: 1.0000 - precision: 0.9899 - recall: 0.9880 - auc: 0.9993 - val_loss: 0.0998 - val_accuracy: 1.0000 - val_precision: 0.9580 - val_recall: 0.9786 - val_auc: 0.9937
# Epoch 5/50
# 50/50 [==============================] - 15s 308ms/step - loss: 0.0139 - accuracy: 1.0000 - precision: 0.9987 - recall: 0.9960 - auc: 1.0000 - val_loss: 0.0799 - val_accuracy: 1.0000 - val_precision: 0.9584 - val_recall: 0.9893 - val_auc: 0.9949
# Epoch 6/50
# 50/50 [==============================] - 17s 336ms/step - loss: 0.0053 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9993 - auc: 1.0000 - val_loss: 0.0961 - val_accuracy: 1.0000 - val_precision: 0.9655 - val_recall: 0.9759 - val_auc: 0.9913
# Epoch 7/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.0020 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1069 - val_accuracy: 1.0000 - val_precision: 0.9652 - val_recall: 0.9678 - val_auc: 0.9935
# Epoch 8/50
# 50/50 [==============================] - 15s 307ms/step - loss: 6.3139e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1050 - val_accuracy: 1.0000 - val_precision: 0.9634 - val_recall: 0.9866 - val_auc: 0.9898
# Epoch 9/50
# 50/50 [==============================] - 16s 324ms/step - loss: 3.9096e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1246 - val_accuracy: 1.0000 - val_precision: 0.9629 - val_recall: 0.9732 - val_auc: 0.9874
# Epoch 10/50
# 50/50 [==============================] - 15s 305ms/step - loss: 2.4656e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1308 - val_accuracy: 1.0000 - val_precision: 0.9630 - val_recall: 0.9759 - val_auc: 0.9863
# Epoch 11/50
# 50/50 [==============================] - 15s 306ms/step - loss: 2.0273e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1243 - val_accuracy: 1.0000 - val_precision: 0.9631 - val_recall: 0.9786 - val_auc: 0.9864
# Epoch 12/50
# 50/50 [==============================] - 15s 307ms/step - loss: 1.7120e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1419 - val_accuracy: 1.0000 - val_precision: 0.9629 - val_recall: 0.9732 - val_auc: 0.9841
# Epoch 13/50
# 50/50 [==============================] - 17s 334ms/step - loss: 1.4853e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1705 - val_accuracy: 1.0000 - val_precision: 0.9600 - val_recall: 0.9651 - val_auc: 0.9833
# Epoch 14/50
# 50/50 [==============================] - 15s 305ms/step - loss: 0.0283 - accuracy: 1.0000 - precision: 0.9940 - recall: 0.9940 - auc: 0.9980 - val_loss: 0.1316 - val_accuracy: 1.0000 - val_precision: 0.9354 - val_recall: 0.9705 - val_auc: 0.9887
# Epoch 15/50
# 50/50 [==============================] - 15s 307ms/step - loss: 0.0164 - accuracy: 1.0000 - precision: 0.9967 - recall: 0.9980 - auc: 1.0000 - val_loss: 0.1206 - val_accuracy: 1.0000 - val_precision: 0.9449 - val_recall: 0.9651 - val_auc: 0.9892
# Epoch 16/50
# 50/50 [==============================] - 16s 328ms/step - loss: 0.0044 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1323 - val_accuracy: 1.0000 - val_precision: 0.9549 - val_recall: 0.9651 - val_auc: 0.9884
# Epoch 17/50
# 50/50 [==============================] - 16s 324ms/step - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1531 - val_accuracy: 1.0000 - val_precision: 0.9500 - val_recall: 0.9678 - val_auc: 0.9850
# Epoch 18/50
# 50/50 [==============================] - 16s 313ms/step - loss: 7.4691e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1714 - val_accuracy: 1.0000 - val_precision: 0.9499 - val_recall: 0.9651 - val_auc: 0.9830
# Epoch 19/50
# 50/50 [==============================] - 16s 304ms/step - loss: 5.1381e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1919 - val_accuracy: 1.0000 - val_precision: 0.9497 - val_recall: 0.9625 - val_auc: 0.9792
# Epoch 20/50
# 50/50 [==============================] - 15s 306ms/step - loss: 3.8779e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1980 - val_accuracy: 1.0000 - val_precision: 0.9447 - val_recall: 0.9625 - val_auc: 0.9781
# Epoch 21/50
# 50/50 [==============================] - 15s 306ms/step - loss: 3.2329e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2008 - val_accuracy: 1.0000 - val_precision: 0.9472 - val_recall: 0.9625 - val_auc: 0.9783
# Epoch 22/50
# 50/50 [==============================] - 15s 307ms/step - loss: 2.5947e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2160 - val_accuracy: 1.0000 - val_precision: 0.9444 - val_recall: 0.9571 - val_auc: 0.9756
# Epoch 23/50
# 50/50 [==============================] - 15s 307ms/step - loss: 2.1908e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2238 - val_accuracy: 1.0000 - val_precision: 0.9444 - val_recall: 0.9571 - val_auc: 0.9756
# Epoch 24/50
# 50/50 [==============================] - 15s 308ms/step - loss: 1.9126e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2287 - val_accuracy: 1.0000 - val_precision: 0.9468 - val_recall: 0.9544 - val_auc: 0.9756
# Epoch 25/50
# 50/50 [==============================] - 16s 326ms/step - loss: 1.6667e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2345 - val_accuracy: 1.0000 - val_precision: 0.9443 - val_recall: 0.9544 - val_auc: 0.9743
# Epoch 26/50
# 50/50 [==============================] - 15s 305ms/step - loss: 0.0130 - accuracy: 1.0000 - precision: 0.9947 - recall: 0.9960 - auc: 0.9999 - val_loss: 0.0999 - val_accuracy: 1.0000 - val_precision: 0.9579 - val_recall: 0.9759 - val_auc: 0.9913
# Epoch 27/50
# 50/50 [==============================] - 15s 302ms/step - loss: 0.0163 - accuracy: 1.0000 - precision: 0.9987 - recall: 0.9926 - auc: 0.9999 - val_loss: 0.1343 - val_accuracy: 1.0000 - val_precision: 0.9602 - val_recall: 0.9705 - val_auc: 0.9857
# Epoch 28/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.0186 - accuracy: 1.0000 - precision: 0.9960 - recall: 0.9946 - auc: 0.9997 - val_loss: 0.1413 - val_accuracy: 1.0000 - val_precision: 0.9744 - val_recall: 0.9169 - val_auc: 0.9900
# Epoch 29/50
# 50/50 [==============================] - 15s 306ms/step - loss: 0.0016 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1599 - val_accuracy: 1.0000 - val_precision: 0.9650 - val_recall: 0.9598 - val_auc: 0.9856
# Epoch 30/50
# 50/50 [==============================] - 15s 307ms/step - loss: 3.8377e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1710 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9857
# Epoch 31/50
# 50/50 [==============================] - 15s 308ms/step - loss: 2.7559e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1831 - val_accuracy: 1.0000 - val_precision: 0.9624 - val_recall: 0.9598 - val_auc: 0.9846
# Epoch 32/50
# 50/50 [==============================] - 16s 321ms/step - loss: 2.1952e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1894 - val_accuracy: 1.0000 - val_precision: 0.9651 - val_recall: 0.9625 - val_auc: 0.9807
# Epoch 33/50
# 50/50 [==============================] - 16s 313ms/step - loss: 1.8351e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.1949 - val_accuracy: 1.0000 - val_precision: 0.9650 - val_recall: 0.9598 - val_auc: 0.9795
# Epoch 34/50
# 50/50 [==============================] - 15s 310ms/step - loss: 1.5776e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2011 - val_accuracy: 1.0000 - val_precision: 0.9650 - val_recall: 0.9598 - val_auc: 0.9782
# Epoch 35/50
# 50/50 [==============================] - 15s 308ms/step - loss: 1.3794e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2055 - val_accuracy: 1.0000 - val_precision: 0.9650 - val_recall: 0.9598 - val_auc: 0.9770
# Epoch 36/50
# 50/50 [==============================] - 15s 305ms/step - loss: 1.2267e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2089 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9770
# Epoch 37/50
# 50/50 [==============================] - 15s 302ms/step - loss: 1.1029e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2131 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9759
# Epoch 38/50
# 50/50 [==============================] - 15s 302ms/step - loss: 9.9776e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2167 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9748
# Epoch 39/50
# 50/50 [==============================] - 15s 296ms/step - loss: 9.1142e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2149 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9762
# Epoch 40/50
# 50/50 [==============================] - 16s 320ms/step - loss: 8.3370e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2168 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9749
# Epoch 41/50
# 50/50 [==============================] - 15s 309ms/step - loss: 7.6717e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2209 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9749
# Epoch 42/50
# 50/50 [==============================] - 16s 313ms/step - loss: 7.1046e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2232 - val_accuracy: 1.0000 - val_precision: 0.9649 - val_recall: 0.9571 - val_auc: 0.9749
# Epoch 43/50
# 50/50 [==============================] - 15s 306ms/step - loss: 6.6007e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2268 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9749
# Epoch 44/50
# 50/50 [==============================] - 16s 315ms/step - loss: 6.1482e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2293 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9749
# Epoch 45/50
# 50/50 [==============================] - 15s 309ms/step - loss: 5.7565e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2311 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9736
# Epoch 46/50
# 50/50 [==============================] - 16s 311ms/step - loss: 5.4115e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2348 - val_accuracy: 1.0000 - val_precision: 0.9648 - val_recall: 0.9544 - val_auc: 0.9736
# Epoch 47/50
# 50/50 [==============================] - 16s 313ms/step - loss: 5.0798e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2378 - val_accuracy: 1.0000 - val_precision: 0.9674 - val_recall: 0.9544 - val_auc: 0.9749
# Epoch 48/50
# 50/50 [==============================] - 16s 325ms/step - loss: 4.7809e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2403 - val_accuracy: 1.0000 - val_precision: 0.9674 - val_recall: 0.9544 - val_auc: 0.9736
# Epoch 49/50
# 50/50 [==============================] - 15s 309ms/step - loss: 4.4991e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2421 - val_accuracy: 1.0000 - val_precision: 0.9674 - val_recall: 0.9544 - val_auc: 0.9736
# Epoch 50/50
# 50/50 [==============================] - 15s 307ms/step - loss: 4.2553e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2441 - val_accuracy: 1.0000 - val_precision: 0.9674 - val_recall: 0.9544 - val_auc: 0.9736

# %%
pred = (model.predict(test_x) > 0.5).astype("int32")

print ( classification_report(pred, test_y))

cm = confusion_matrix(test_y, pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='', cbar=False, linewidths=2,
            xticklabels = ['Fake','Real'], yticklabels = ['Fake','Real'])
plt.title('confusion matrix')
plt.xlabel('Predicted', color='navy', fontsize=15)
plt.ylabel('Actual', color='navy', fontsize=15);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       414
#            1       0.99      0.96      0.97       384
#
#     accuracy                           0.97       798
#    macro avg       0.97      0.97      0.97       798
# weighted avg       0.97      0.97      0.97       798

# %%
acc = history.history['recall']
val_acc = history.history['val_recall']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['val_loss']))
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.scatter(epochs_range, acc, label='Training Recall')
plt.scatter(epochs_range, val_acc, label='Validation Recall')
plt.legend(loc='lower right')
plt.title('Training and Validation Recall')
plt.subplot(1, 2, 2)
plt.scatter(epochs_range, loss, label='Training Loss')
plt.scatter(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
